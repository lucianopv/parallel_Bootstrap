# %%
import numpy as np
# import pandas as pd
from scipy.optimize import minimize, minimize_scalar
import matplotlib.pyplot as plt

def objective(x):
    x1 = x[0]
    x2 = x[1]
    x3 = x[2]
    return(x1**2 + x2** 2 + x3**2 + 2*x1 + 2*x2 + 2*x3 - x1*x2 - x2*x3 + 3)

bounds = ((-9, 9), (-9, 9), (-9,9))

x0 = np.array([0]*3)

res = minimize(objective, x0 = x0, bounds = bounds, method = 'SLSQP')

# %%
res['x']
# Out:
# array([-2.99999973, -3.99999977, -2.99999973])

# %%
# Out:
# -3.000000000000128

# %%
plt.plot(y)

# %%
def sim_one():
    from numpy.random import randint
    test_list = (randint(0,365,300)).tolist()
    test_list.sort()
    rang = 100
    res = test_list[0] 
    for i in range(len(test_list)): 
        freq =  
        if freq > max: 
            max = freq 
            res = i
    return max

res = []
for i in range(100000):
    res.append(int(sim_one() >= 3))
# Out:
# dict_values([array([-2.99999973, -3.99999977, -2.99999973]), -6.999999999999927, array([ 2.38418579e-07, -2.38418579e-07,  2.38418579e-07]), 5, 26, 5, 0, 'Optimization terminated successfully.', True])

# %%
numbers = (np.random.randint(0,365,300)).tolist()
numbers.sort()
numbers
# Out:
# [1,
#  5,
#  8,
#  9,
#  10,
#  10,
#  14,
#  15,
#  17,
#  18,
#  18,
#  23,
#  29,
#  31,
#  32,
#  33,
#  33,
#  35,
#  37,
#  39,
#  42,
#  43,
#  44,
#  49,
#  50,
#  52,
#  53,
#  54,
#  55,
#  55,
#  57,
#  59,
#  60,
#  60,
#  61,
#  61,
#  61,
#  62,
#  62,
#  62,
#  64,
#  64,
#  65,
#  65,
#  66,
#  67,
#  67,
#  68,
#  71,
#  75,
#  75,
#  76,
#  76,
#  76,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  84,
#  86,
#  87,
#  89,
#  89,
#  89,
#  93,
#  94,
#  95,
#  99,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  106,
#  106,
#  108,
#  111,
#  111,
#  113,
#  115,
#  116,
#  116,
#  117,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  129,
#  130,
#  131,
#  132,
#  133,
#  135,
#  137,
#  138,
#  140,
#  143,
#  144,
#  144,
#  145,
#  146,
#  150,
#  151,
#  152,
#  153,
#  153,
#  153,
#  153,
#  154,
#  154,
#  154,
#  155,
#  157,
#  157,
#  157,
#  158,
#  158,
#  160,
#  160,
#  162,
#  163,
#  165,
# ...

# %%
from itertools import combinations
def sim_one(x):
    sample = np.random.choice(x, 100)
    comb = list(combinations(sample, 2))
    count = 0
    for c in comb:
        if c[0] - c[1] < 100 | c[0] - c[1] > -100 | (99 - c[0]) + (365 - c[1]) < 100 | (99 - c[1]) + (365 - c[0]) < 100:
            count += 1
    return(count/len(comb))



res = [sim_one(numbers) for n in range(1000)]

# %%
np.mean(res)
# Out:
# 0.708810101010101
